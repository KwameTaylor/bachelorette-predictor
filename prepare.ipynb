# %% [markdown]
# # Data Preparation for the Bachelorette Predictor
# ### Kwame V. Taylor
#
# I need to join the data from ```bachelorette_edit-to-join.csv``` with the data from ```bachelorette-contestants.csv```.

# %% [markdown]
# ### Set up env and load data

# %%
import numpy as np
import pandas as pd
import re

# %%
df = pd.read_csv('bachelorette-contestants.csv', index_col='Name')
join = pd.read_csv('bachelorette_edit-to-join.csv')

# %%
df.head()
# Out:
#                Age         Occupation                   Hometown  ElimWeek  \
# Name
# Ryan Sutter     29        Firefighter             Vail, Colorado       NaN
# Charlie Maher   28  Financial Analyst  Hermosa Beach, California       6.0
# Russ            30             Writer     San Rafael, California       5.0
# Greg T.         28           Importer        Manhattan, New York       4.0
# Bob Guiney      31    Mortgage Broker         Ferndale, Michigan       3.0
#
#                Season
# Name
# Ryan Sutter         1
# Charlie Maher       1
# Russ                1
# Greg T.             1
# Bob Guiney          1

# %%
join.head()
# Out:
#    SEASON   CONTESTANT ELIMINATION-1 ELIMINATION-2 ELIMINATION-3  \
# 0      12  12_JORDAN_R            R1           NaN           NaN
# 1      12   12_ROBBY_H           NaN           NaN           NaN
# 2      12   12_CHASE_M           NaN           NaN             R
# 3      12    12_LUKE_P           NaN           NaN           NaN
# 4      12   12_JAMES_T           NaN             R             R
#
#   ELIMINATION-4 ELIMINATION-5 ELIMINATION-6 ELIMINATION-7 ELIMINATION-8  ...  \
# 0             R             R           NaN           NaN           NaN  ...
# 1           NaN             R           NaN             R           NaN  ...
# 2           NaN           NaN             R           NaN           NaN  ...
# 3             R           NaN             R           NaN             E  ...
# 4           NaN           NaN           NaN             E           NaN  ...
#
#   DATES-1 DATES-2  DATES-3 DATES-4 DATES-5 DATES-6 DATES-7 DATES-8 DATES-9  \
# ...

# %% [markdown]
# ### Clean up contestant names on both DataFrames

# %% [markdown]
# **```join``` df**

# %%
# replace the matching strings 
join.CONTESTANT = join.CONTESTANT.replace(to_replace ='\d+(_)', value = '', regex = True) 
  
# Print the updated dataframe 
join.head()
# Out:
#    SEASON CONTESTANT ELIMINATION-1 ELIMINATION-2 ELIMINATION-3 ELIMINATION-4  \
# 0      12   JORDAN_R            R1           NaN           NaN             R
# 1      12    ROBBY_H           NaN           NaN           NaN           NaN
# 2      12    CHASE_M           NaN           NaN             R           NaN
# 3      12     LUKE_P           NaN           NaN           NaN             R
# 4      12    JAMES_T           NaN             R             R           NaN
#
#   ELIMINATION-5 ELIMINATION-6 ELIMINATION-7 ELIMINATION-8  ... DATES-1  \
# 0             R           NaN           NaN           NaN  ...     NaN
# 1             R           NaN             R           NaN  ...     NaN
# 2           NaN             R           NaN           NaN  ...     NaN
# 3           NaN             R           NaN             E  ...     NaN
# 4           NaN           NaN             E           NaN  ...     NaN
#
#   DATES-2  DATES-3 DATES-4 DATES-5 DATES-6 DATES-7 DATES-8 DATES-9 DATES-10
# ...

# %%
#join[join['SEASON'] == 1]

# %% [markdown]
# **```df``` df**

# %% [raw]
# Ryan Sutter
# Charlie Maher
# Russ
# Greg T.
# Bob Guiney

# %% [markdown]
# 1. Turn last name into just the first letter (if there is a last name)
# 2. Add '_X' if there is no last name
# 3. Remove periods
# 4. Replace the space with a '_'
# 5. Uppercase all

# %%
regex1 = r'( )\w+.'
regex2 = 
regex3 = 
regex4 =
# Out:
#   File "<ipython-input-38-69a2257a9291>", line 2
#     regex2 =
#              ^
# SyntaxError: invalid syntax

# %%
regex1 = r'( )\w+.'

# Turn last name into just the first letter (if there is a last name)
df_updated = df.replace(to_replace = regex1, value = r'( )\w', regex = True)

# Print the updated dataframe 
df_updated.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.8/sre_parse.py in parse_template(source, state)
#    1038                 try:
# -> 1039                     this = chr(ESCAPES[this][1])
#    1040                 except KeyError:
#
# KeyError: '\\w'
#
# During handling of the above exception, another exception occurred:
#
# error                                     Traceback (most recent call last)
# <ipython-input-39-814e6942ea71> in <module>
#       2
#       3 # Turn last name into just the first letter (if there is a last name)
# ----> 4 df_updated = df.replace(to_replace = regex1, value = r'( )\w', regex = True)
#       5
#       6 # Print the updated dataframe
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4381         method="pad",
# ...

# %%
# Turn last name into just the first letter (if there is a last name)
df_updated = df.replace(to_replace = regex1, value = r'( )\w', regex = True)

# replace the matching strings 
df_updated = df.replace(to_replace = regex2, value = '', regex = True)

# replace the matching strings 
df_updated = df.replace(to_replace = regex3, value = '', regex = True)

# replace the matching strings
df_updated = df.replace(to_replace = regex4, value = '', regex = True)

# uppercase all
df_updated = 

# Print the updated dataframe 
df_updated.head()

# %% [markdown]
# ### Check for duplicates
